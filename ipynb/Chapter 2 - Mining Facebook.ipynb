# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool

ACCESS_TOKEN = 'CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD'

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,friends.limit(10).fields(likes.limit(10))'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print url

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print json.dumps(content, indent=1)
# Out:
# https://graph.facebook.com/me?fields=id,name,friends.limit(10).fields(likes.limit(10))&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD
# {
#  "friends": {
#   "paging": {
#    "next": "https://graph.facebook.com/v1.0/10205232763448624/friends?limit=10&fields=likes.limit%2810%29&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&offset=10&__after_id=enc_AezoQHjotPDhHZX5eY_6vwIqclrS4rF2H76--Sx3viQ3DVECa4-M90dY495A_d2YDus2NXvccKG7F2mGodpyu7Cm"
#   },
#   "data": [
#    {
#     "id": "10152177237825766"
#    },
#    {
#     "id": "888580231158837",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MzczMDU3NjM2MTYwNTkx",
#        "before": "MzIxMTY5OTY0NzI1MzM0"
#       },
#       "next": "https://graph.facebook.com/v1.0/888580231158837/likes?limit=10&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&after=MzczMDU3NjM2MTYwNTkx"
#      },
#      "data": [
#       {
#        "category": "Public figure",
#        "created_time": "2014-08-12T01:50:01+0000",
#        "name": "Yoshio Avila",
#        "id": "321169964725334"
#       },
#       {
#        "category": "Athlete",
#        "created_time": "2014-08-06T07:38:59+0000",
#        "name": "Becky Hammon",
#        "id": "108396395849213"
#       },
#       {
#        "category": "Magazine",
#        "created_time": "2014-06-21T23:52:45+0000",
#        "name": "Dc Comics M\u00e9xico",
#        "id": "257152901005877"
#       },
#       {
#        "category": "Media/news/publishing",
#        "created_time": "2014-06-13T04:46:00+0000",
#        "name": "ESPN Careers",
#        "id": "167793409941756"
#       },
#       {
#        "category": "Magazine",
#        "created_time": "2014-06-05T19:26:25+0000",
#        "name": "Ideas Creativas",
#        "id": "267333073438841"
#       },
#       {
#        "category": "Tv show",
#        "created_time": "2014-05-30T19:10:21+0000",
#        "name": "Nacion ESPN",
#        "id": "144139432262772"
#       },
#       {
#        "category": "Recreation/sports website",
#        "created_time": "2014-05-27T16:30:28+0000",
#        "name": "Basketball Drills and Plays",
#        "id": "113769942019382"
#       },
#       {
#        "category": "Writer",
#        "created_time": "2014-05-27T04:19:09+0000",
#        "name": "Stan Lee",
#        "id": "26500661542"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2014-05-20T17:34:22+0000",
#        "name": "Unofficial: Banksy",
#        "id": "1471162443107177"
#       },
#       {
#        "category": "Actor/director",
#        "created_time": "2014-05-18T01:26:34+0000",
#        "name": "Ana Gonzalez Bello",
#        "id": "373057636160591"
#       }
#      ]
#     }
#    },
#    {
#     "id": "100000639323606",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTc5MjExMzQ1NTI1ODMz",
#        "before": "Mjk5MzgyNzEzNTYyOTMw"
#       },
#       "next": "https://graph.facebook.com/v1.0/100000639323606/likes?limit=10&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&after=MTc5MjExMzQ1NTI1ODMz"
#      },
#      "data": [
#       {
#        "category": "Movie character",
#        "created_time": "2014-10-26T01:34:28+0000",
#        "name": "The Head Shot KillaZ - LEMR",
#        "id": "299382713562930"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2014-08-28T01:20:01+0000",
#        "name": "El Local \" Mod Games \"",
#        "category_list": [
#         {
#          "id": "139823692748565",
#          "name": "Computers & Electronics"
#         }
#        ],
#        "id": "257364217741166"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-06-02T14:02:53+0000",
#        "name": "Zirel",
#        "id": "844949845534305"
#       },
#       {
#        "category": "Artist",
#        "created_time": "2014-05-13T17:51:32+0000",
#        "name": "Spainfury Youtube",
#        "id": "1381417018799184"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-04-01T04:41:08+0000",
#        "name": "Meretrix-Music",
#        "id": "609595555782412"
#       },
#       {
#        "category": "Entertainment website",
#        "created_time": "2014-03-17T07:03:05+0000",
#        "name": "Mejores v\u00eddeos",
#        "id": "647566031979234"
#       },
#       {
#        "category": "Entertainer",
#        "created_time": "2014-01-30T04:29:51+0000",
#        "name": "bysTaXx",
#        "id": "134148526727065"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2014-01-29T08:23:43+0000",
#        "name": "Willyrex",
#        "id": "162597417232850"
#       },
#       {
#        "category": "Entertainer",
#        "created_time": "2013-12-26T01:04:20+0000",
#        "name": "ElrubiusOMG",
#        "id": "337992166223323"
#       },
#       {
#        "category": "Radio station",
#        "created_time": "2013-10-23T22:26:36+0000",
#        "name": "Amor1037 Veracruz",
#        "id": "179211345525833"
#       }
#      ]
#     }
#    }
#   ]
#  },
#  "id": "10205232763448624",
#  "name": "Jos\u00e9 Manuel Proudinat Silva"
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print json.dumps(o, indent=1)

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print '---------------'
print 'Me'
print '---------------'
pp(g.get_object('me'))
print
print '---------------'
print 'My Friends'
print '---------------'
pp(g.get_connections('me', 'friends'))
print
print '---------------'
print 'Social Web'
print '---------------'
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "last_name": "Proudinat Silva",
#  "locale": "es_LA",
#  "hometown": {
#   "id": "107912095904228",
#   "name": "Veracruz, Veracruz"
#  },
#  "favorite_teams": [
#   {
#    "id": "175998575892899",
#    "name": "Cloud9"
#   },
#   {
#    "id": "1429179963963853",
#    "name": "BrawL"
#   },
#   {
#    "id": "347737541994357",
#    "name": "Lyon Gaming"
#   }
#  ],
#  "favorite_athletes": [
#   {
#    "id": "341265789340016",
#    "name": "Lolirot"
#   }
#  ],
#  "timezone": -6,
#  "education": [
#   {
#    "school": {
#     "id": "110718362289436",
#     "name": "Instituto Tecnologico Autonomo de Mexico (ITAM)"
#    },
#    "type": "High School"
#   },
#   {
#    "school": {
#     "id": "635188709836416",
#     "name": "Colegio Villa Rica"
#    },
#    "type": "High School",
#    "year": {
#     "id": "201638419856163",
#     "name": "2011"
#    }
#   },
#   {
#    "school": {
#     "id": "119718518045622",
#     "name": "ITESM CCV"
#    },
#    "type": "High School"
#   },
#   {
#    "school": {
#     "id": "108583112500279",
#     "name": "Instituto Tecnol\u00f3gico Aut\u00f3nomo de M\u00e9xico"
#    },
#    "type": "College"
#   },
#   {
#    "school": {
#     "id": "111150122239484",
#     "name": "Instituto Tecnol\u00f3gico Aut\u00f3nomo de M\u00e9xico"
#    },
#    "type": "College"
#   }
#  ],
#  "id": "10205232763448624",
#  "first_name": "Jos\u00e9",
#  "middle_name": "Manuel",
#  "religion": "Christ 4 Life!",
#  "location": {
#   "id": "107912095904228",
#   "name": "Veracruz, Veracruz"
#  },
#  "email": "jmps2812@gmail.com",
#  "username": "josman2812",
#  "bio": "jmps_2812@hotmail.com\r\nhttp://twitter.com/JosmanPS",
#  "birthday": "12/28/1992",
#  "link": "https://www.facebook.com/josman2812",
#  "verified": true,
#  "name": "Jos\u00e9 Manuel Proudinat Silva",
#  "gender": "male",
#  "work": [
#   {
#    "employer": {
#     "id": "554253181345916",
#     "name": "Datata"
#    }
#   },
#   {
#    "employer": {
#     "id": "105983419441849",
#     "name": "Colegio Villa Rica"
#    }
#   }
#  ],
#  "updated_time": "2014-10-17T05:51:36+0000",
#  "interested_in": [
#   "female"
#  ]
# }
# ---------------
# My Friends
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/10205232763448624/friends?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=5000&offset=5000&__after_id=enc_AeyarEyh5jBU7u--LhNAEMubVBfQitzk2uuczwCuGygedrTUtPJ3faUDnF4wcCTq-MnDsioq6es3v5nVu46WTNO8"
#  },
#  "data": [
#   {
#    "name": "Mar\u00eda Fernanda Borge",
#    "id": "10152177237825766"
#   },
#   {
#    "name": "Juan Pedro Luengas",
#    "id": "888580231158837"
#   },
#   {
#    "name": "Olliver Saul Flores",
#    "id": "100000639323606"
#   }
#  ]
# }
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?type=page&q=social+web&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=5000&offset=5000&__after_id=enc_Aeyj3IeikikTe-alGBcTsx4w3Zsi2hbRv0rAGKWg3J9_DfHgnSVO60dzfqFmQ04INcZzVJo0TG2Bpz3arufSTquP"
#  },
#  "data": [
#   {
#    "category": "Professional services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "145218172174013"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead senegal",
#    "id": "344899405678326"
#   },
#   {
#    "category": "Website",
#    "name": "Social Webshop",
#    "id": "1394913830760636"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialWeb",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "669751383086793"
#   },
#   {
#    "category": "Business services",
#    "name": "socialWEB",
#    "category_list": [
#     {
#      "id": "200209719995975",
#      "name": "Business Supply Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "114355558650055"
#   },
#   {
#    "category": "Software",
#    "name": "SocialWebshop Poland",
#    "id": "853892051289097"
#   },
#   {
#    "category": "Movie theater",
#    "name": "Social Webshop UK",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "367809806695037"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "275989642418291"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialWebMarketing",
#    "id": "226633110719998"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cafe",
#    "id": "255596497809113"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWeb.ro",
#    "id": "185753574790507"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webs",
#    "id": "174735529355893"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social & Web Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "172427156148334"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Girl",
#    "id": "1425389227704470"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webforce",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "128172607258182"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social webs cheats",
#    "id": "227273367442760"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Nerd",
#    "id": "121955387828900"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Websoftseo Social",
#    "id": "378379822329057"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "181475575221097",
#      "name": "Photographer"
#     }
#    ],
#    "id": "144307838980365"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Website",
#    "id": "210604392401626"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web Reporter",
#    "id": "598817503529463"
#   },
#   {
#    "category": "Radio station",
#    "name": "WebRadio Social",
#    "id": "172438649562650"
#   },
#   {
#    "category": "Education",
#    "name": "WebSocial",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "192541364117143"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Alliance",
#    "id": "160477007390933"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social / Web Marketing Agency - Stir USA | Canada",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "152246029758"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialWebshops",
#    "id": "648911958521685"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop FR",
#    "id": "235406569990322"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "My Social Web",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ],
#    "id": "76277666156"
#   },
#   {
#    "category": "App page",
#    "name": "SocialWebbie",
#    "id": "217112891701827"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ],
#    "id": "162973743866087"
#   },
#   {
#    "category": "Community",
#    "name": "Web social life",
#    "id": "209254342562410"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webs",
#    "id": "678244902251294"
#   },
#   {
#    "category": "Arts/humanities website",
#    "name": "Social Web Art",
#    "id": "833575423359366"
#   },
#   {
#    "category": "Interest",
#    "name": "Social web",
#    "id": "112879218725926"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Dzine",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "122698737762622"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Caroline Webb   Digital & Social Media",
#    "id": "219957014881658"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Innovation",
#    "id": "162028037196792"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Factory",
#    "id": "67783847861"
#   },
#   {
#    "category": "Local business",
#    "name": "Social web design by x10industries",
#    "id": "330043283780"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Day",
#    "id": "137161799695400"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Ranking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "470852336273104"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "103944626326539"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWebOS",
#    "category_list": [
#     {
#      "id": "2703",
#      "name": "Computers/Internet Website"
#     }
#    ],
#    "id": "358524254168284"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Associates",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "327997047315600"
#   },
#   {
#    "category": "Product/service",
#    "name": "On The Webb Social Media Services",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "210125749066257"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "SOCIAL WEBSITE",
#    "id": "290608457641244"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Consulting",
#    "id": "248823435257496"
#   },
#   {
#    "category": "Business services",
#    "name": "Thinking Social",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "564197383702741"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Veranet SocialMedia",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "312929368858881"
#   },
#   {
#    "category": "Professional services",
#    "name": "Visibly Connected - Web Design, Social Media Manager, & SEO",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "190805541029564"
#   },
#   {
#    "category": "Professional services",
#    "name": "ISocial Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "691387304273877"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Siti Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "553637281423867"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Webmates",
#    "id": "474170526056354"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Genesis Web Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "186129094876663"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Webmarks",
#    "id": "230470560302996"
#   },
#   {
#    "category": "Book",
#    "name": "Mining the Social Web",
#    "id": "146803958708175"
#   },
#   {
#    "category": "Company",
#    "name": "Weber Shandwick Social Impact",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "89444069963"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "441220109348770"
#   },
#   {
#    "category": "Musician/band",
#    "name": "WebtonSocial",
#    "id": "151651414881841"
#   },
#   {
#    "category": "Community organization",
#    "name": "Social Web Tech Talk",
#    "id": "173272359544586"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Tools",
#    "id": "403059893050740"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "In Social Web",
#    "id": "168072826666497"
#   },
#   {
#    "category": "Tv network",
#    "name": "Ceflix social web tv",
#    "id": "760164607375916"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social WEB",
#    "id": "644404665577920"
#   },
#   {
#    "category": "Local business",
#    "name": "Spider Web Social Media Management",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "819787441388121"
#   },
#   {
#    "category": "Small business",
#    "name": "Elevate5 Web + Social Media",
#    "id": "825830494107856"
#   },
#   {
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1",
#    "id": "419507011456285"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webology",
#    "id": "199369666770042"
#   },
#   {
#    "category": "Education",
#    "name": "Social Web Academy",
#    "id": "192046090848741"
#   },
#   {
#    "category": "Local business",
#    "name": "eitbits Webs & Social Media",
#    "id": "132214966858612"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "iSocialWeb",
#    "id": "462294513847158"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "156184496617"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web Thing",
#    "id": "114874051893438"
#   },
#   {
#    "category": "Community",
#    "name": "Webster Alumni Social Group",
#    "id": "487171701376262"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop Italy",
#    "id": "610458242362481"
#   },
#   {
#    "category": "Concert venue",
#    "name": "SocialWeb",
#    "id": "186493478082456"
#   },
#   {
#    "category": "Company",
#    "name": "Social web consulting",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "438991686226624"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webfluence Social Media & Internet Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "112879788755706"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Clases de lo social - La Webserie",
#    "id": "280735022054806"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Websurf Social Media",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "102106206533278"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Web Talks",
#    "id": "316613681700247"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web.Search.Social",
#    "id": "214631441934914"
#   },
#   {
#    "category": "Community organization",
#    "name": "SocialWebConneXion.com",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "152880021441864",
#      "name": "Community Organization"
#     }
#    ],
#    "id": "636570933034875"
#   },
#   {
#    "category": "Community",
#    "name": "Social Webs",
#    "id": "159735864118250"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial",
#    "id": "208290102524008"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web BREAKFAST",
#    "id": "175318852545291"
#   },
#   {
#    "category": "Website",
#    "name": "Islamic & Social Website - abswerbd.com",
#    "id": "677061112307489"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Gym",
#    "category_list": [
#     {
#      "id": "185900881450649",
#      "name": "Personal Coaching"
#     }
#    ],
#    "id": "488323237847526"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "502604446522710"
#   },
#   {
#    "category": "Internet/software",
#    "name": "FUA Social Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "1410567895848855"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social",
#    "id": "481173118576926"
#   },
#   {
#    "category": "Website",
#    "name": "My Social Media Website",
#    "id": "265276823522152"
#   },
#   {
#    "category": "Home improvement",
#    "name": "Websites & Social Media",
#    "category_list": [
#     {
#      "id": "108427109235243",
#      "name": "Home Improvement"
#     }
#    ],
#    "id": "213642188759243"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Milano Social Web",
#    "id": "252633804884736"
#   },
#   {
#    "category": "Professional services",
#    "name": "WebSpot Social",
#    "id": "175322602545416"
#   },
#   {
#    "category": "Community",
#    "name": "Social WEB",
#    "id": "295703510589892"
#   },
#   {
#    "category": "Small business",
#    "name": "Ignite Social Web",
#    "id": "124131750957589"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar commune biscuiterie",
#    "id": "557707754330768"
#   },
#   {
#    "category": "Community",
#    "name": "Web Social",
#    "id": "231682236924947"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social-Webcam",
#    "id": "138187269563360"
#   },
#   {
#    "category": "Organization",
#    "name": "SocialWeb.in",
#    "id": "680577328699377"
#   },
#   {
#    "category": "Company",
#    "name": "SW Social Web",
#    "id": "209972042367716"
#   },
#   {
#    "category": "Website",
#    "name": "Web Social Tourism",
#    "id": "301608313292038"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Promotions",
#    "id": "234335963269949"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social WebNet LLC",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "214860238659493"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Dev",
#    "id": "233682666821223"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Social4Web",
#    "id": "169765039795027"
#   },
#   {
#    "category": "Internet/software",
#    "name": "viermalvier.at - Social Multi Media",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "119350824757721"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialNetworks Pro",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     }
#    ],
#    "id": "349356101889900"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialTab Web Apps",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "271649089705217"
#   },
#   {
#    "category": "Local business",
#    "name": "Quisk Design - Websites, Branding & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "328671177050"
#   },
#   {
#    "category": "Local business",
#    "name": "Barclay Jones - Recruitment Technology and Social Media",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "104235069630517"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "webfeuer - Social Media und mehr!",
#    "id": "369613539636"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webdesign",
#    "id": "220350687983200"
#   },
#   {
#    "category": "Company",
#    "name": "Webshoutz be social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "502559819771053"
#   },
#   {
#    "category": "Local business",
#    "name": "Web1 Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "119307778101744"
#   },
#   {
#    "category": "Website",
#    "name": "Social/News/Culture Website",
#    "id": "1450059198607934"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "192119584190796",
#      "name": "Event"
#     },
#     {
#      "id": "108470879231339",
#      "name": "Research Service"
#     }
#    ],
#    "id": "147895125402338"
#   },
#   {
#    "category": "Company",
#    "name": "Hi Fi Social Web",
#    "id": "196298563744277"
#   },
#   {
#    "category": "Teacher",
#    "name": "Dise\u00f1o Web Social - Josu Salvador y Olaz\u00e1bal",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "253202708077866"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Web Cafe TV",
#    "id": "149184731910179"
#   },
#   {
#    "category": "Company",
#    "name": "SocialWeb Consulting",
#    "id": "177391935634180"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Wizard",
#    "id": "169089429771025"
#   },
#   {
#    "category": "Business services",
#    "name": "Boxless Media - Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "150063728530867"
#   },
#   {
#    "category": "App page",
#    "name": "Web Social Mania",
#    "id": "445746788774576"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Strategies",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "8387137434"
#   },
#   {
#    "category": "Artist",
#    "name": "Ion Gonzaga, The Social Web Designer",
#    "id": "120679007979099"
#   },
#   {
#    "category": "Interest",
#    "name": "Social website",
#    "id": "198566960212311"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Web-social.marketing",
#    "id": "1469299413303540"
#   },
#   {
#    "category": "Movie theater",
#    "name": "Webear.ning.com",
#    "id": "201297245816"
#   },
#   {
#    "category": "Business services",
#    "name": "Website Social Media Development",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "522531034450480"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media & Website Solutions by 108 degrees",
#    "id": "125953907477790"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Whirlwind Web & Social Media",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "387289678016550"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media & Websites",
#    "id": "278572212299892"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Ecosystem",
#    "id": "186923664693877"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "The Social Web Company",
#    "id": "460355617439986"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Bee Web Marketing and Design",
#    "id": "187494864706626"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "118119234870548"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "WeBaloch - First Balochi Social Network",
#    "id": "310645388963015"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Gimme Social Web",
#    "id": "190870261096138"
#   },
#   {
#    "category": "Local business",
#    "name": "WebSocialTraffic",
#    "id": "19939664284"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Bonobo - Web & Social Media",
#    "id": "185366164983180"
#   },
#   {
#    "category": "Product/service",
#    "name": "Eguino Social Web",
#    "id": "114206991977394"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Impact Web",
#    "id": "196321800413834"
#   },
#   {
#    "category": "Local business",
#    "name": "etrade.ba | Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "217376194979375"
#   },
#   {
#    "category": "Product/service",
#    "name": "Mr Webinators |  Social Media Professional | Wahooligan's Wall",
#    "category_list": [
#     {
#      "id": "2201",
#      "name": "Product/Service"
#     }
#    ],
#    "id": "317645416802"
#   },
#   {
#    "category": "Local business",
#    "name": "Biz Social Webdesign / Web Design by Jenn",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "115395771827453"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Media Webster",
#    "id": "416689008392125"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "The Social Media Web Genie",
#    "id": "537321239622767"
#   },
#   {
#    "category": "Professional services",
#    "name": "Local Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "292125494205150"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar m\u00e9dina",
#    "id": "662546880510024"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Real Estate",
#    "id": "164269200441810"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Meta Social Web",
#    "id": "117185225027930"
#   },
#   {
#    "category": "Local business",
#    "name": "Marketing Web Social",
#    "id": "292769827406517"
#   },
#   {
#    "category": "Website",
#    "name": "Latin Web Social",
#    "id": "144860758877785"
#   },
#   {
#    "category": "Community",
#    "name": "ITE College Central - Social Media & Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "120366748050821"
#   },
#   {
#    "category": "Community",
#    "name": "WebSocial",
#    "id": "787573591283803"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Emma Fern\u00e1ndez \u00b7SEO \u00b7 Web \u00b7Social Media",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "658425767604330"
#   },
#   {
#    "category": "Professional services",
#    "name": "Free Social Media Webinars",
#    "id": "1388018764754564"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Adapting Social Web Design & Digital Marketing",
#    "id": "232898900191494"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Q and A",
#    "id": "433133770070530"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "G&B Marketing | Web & Social Media",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "331604230252618"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Communication",
#    "category_list": [
#     {
#      "id": "132008380200065",
#      "name": "Image Consultant"
#     }
#    ],
#    "id": "165807746962152"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Design",
#    "id": "281249708648873"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar grand yoff",
#    "id": "521762104627077"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Tomeito - Web, App y Publicidad Online",
#    "id": "166490826827066"
#   },
#   {
#    "category": "Business services",
#    "name": "LS Social Web",
#    "id": "515092701968229"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social Web Games",
#    "id": "303818923034509"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web CT",
#    "id": "133897929978754"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialEnterpriseWebsites.com",
#    "id": "208744325821683"
#   },
#   {
#    "category": "Personal website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE",
#    "id": "114852928532072"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Leading Logic - Web, Social, Marketing, Design",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "136481676384923"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Promoter",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "657099161012700"
#   },
#   {
#    "category": "Local business",
#    "name": "Dot Ingenuity Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "131570646875176"
#   },
#   {
#    "category": "Community organization",
#    "name": "Go Long Island - The Social Website for Long Island",
#    "id": "118029078273421"
#   },
#   {
#    "category": "Website",
#    "name": "Mike Mueller: Marketing, Web Design, & Social Media Consultation",
#    "id": "50818804012"
#   },
#   {
#    "category": "Company",
#    "name": "Sweden Social Web Camp",
#    "id": "290284817827"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "107061159384322"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media On The Web",
#    "id": "155217227871015"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Power",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "835021083188471"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Dreams: Web Series",
#    "id": "612698088813986"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Web Media",
#    "id": "198866480158068"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Jenna McWatters - Web Design and Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "1416729695251458"
#   },
#   {
#    "category": "Community",
#    "name": "Webchat.my IRC Social Network",
#    "id": "398080426963854"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "125310277520246"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Media Websites",
#    "id": "121361064703333"
#   },
#   {
#    "category": "Local business",
#    "name": "CREAKTIVA - publicidad \u2022 dise\u00f1o web \u2022 gr\u00e1fico \u2022 social media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "146914405366023"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Palm Springs TRU Websites/Social Media",
#    "id": "1454453034787354"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Week Connecticut",
#    "id": "128455980522180"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Jasa Buat Web Social Media",
#    "id": "299273933600876"
#   },
#   {
#    "category": "Personal website",
#    "name": "V Crown Social website",
#    "id": "509251595812044"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web/Social Marketing",
#    "id": "172670552803004"
#   },
#   {
#    "category": "Internet/software",
#    "name": "WebKit - Social Networks, E-commerce, Web Development",
#    "id": "96394316810"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Real-time Social Web",
#    "id": "121363354543881"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Wedding Social Networking, Free Wedding Websites",
#    "id": "187276274416"
#   },
#   {
#    "category": "Internet/software",
#    "name": "The  Crew & Co Web & Social Media Solutions",
#    "id": "393828227336141"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "DEGRAFIK - Social Media and Website Management",
#    "id": "113648292011480"
#   },
#   {
#    "category": "News/media website",
#    "name": "SocialWebSeries",
#    "id": "245057172212562"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Webinarcamps",
#    "id": "508178575883032"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Website Designing in Dubai, Website Development,Social Media Marketing-seo",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     }
#    ],
#    "id": "1392517094365062"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar dieupeul derkle",
#    "id": "386488081503891"
#   },
#   {
#    "category": "Community",
#    "name": "Social & Web",
#    "id": "210891895758876"
#   },
#   {
#    "category": "Website",
#    "name": "Webverts Social Coupons",
#    "id": "290755324388883"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Qweboo \"Control Your Social Web\"",
#    "id": "146142715411167"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Website Design Tutorials And Social Media Marketing",
#    "id": "418218642781"
#   },
#   {
#    "category": "Teens/kids website",
#    "name": "Web Social",
#    "id": "439935936081318"
#   },
#   {
#    "category": "Professional services",
#    "name": "Widows Web Tattoo & Social Club",
#    "category_list": [
#     {
#      "id": "196188420407122",
#      "name": "Tattoo & Piercing"
#     }
#    ],
#    "id": "1508522469377417"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Blog",
#    "id": "120064018007609"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Leads",
#    "id": "118076131540902"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "East West Websites & Social Media",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "258436910980966"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web",
#    "id": "456664834354636"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar pikine",
#    "id": "1486223964986147"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar jaxaay niakoulrab rufisque",
#    "id": "1466275763633531"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar keur massar",
#    "id": "279885212222490"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar thiaroye kao",
#    "id": "1487671954851143"
#   },
#   {
#    "category": "Product/service",
#    "name": "@webdesignleads - Web Design & Development Social Leads",
#    "id": "162899293739458"
#   },
#   {
#    "category": "Retail and consumer merchandise",
#    "name": "Social Network Webshop",
#    "id": "424002204310411"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Act",
#    "id": "583432211721362"
#   },
#   {
#    "category": "Local business",
#    "name": "Ed Doherty Jr. - SEO, Social, Web Design",
#    "id": "519084648117730"
#   },
#   {
#    "category": "Internet/software",
#    "name": "bluehouse - Die Web & Social Media Agentur",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "223239324395549"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Web Works",
#    "id": "571161142901860"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Communication",
#    "id": "712032982208651"
#   },
#   {
#    "category": "Personal website",
#    "name": "My Friends Book ~ Social Networking Website",
#    "id": "249459055096850"
#   },
#   {
#    "category": "Community",
#    "name": "Webcam Poker Social",
#    "id": "712417472183392"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar parcelles",
#    "id": "871079359593314"
#   },
#   {
#    "category": "Professional services",
#    "name": "Computer Web Social Media of Shelby",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "207112126105577"
#   },
#   {
#    "category": "Website",
#    "name": "Social Media Webinar",
#    "id": "119970001420128"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Kreativevue Web Design & Social Media",
#    "id": "426710170752907"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Web Brasil",
#    "id": "363231467061867"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Traffic & Social Networking",
#    "id": "159898507447542"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ICTIP - Online Marketing, Social Media Management and Web Development",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "147188657823"
#   },
#   {
#    "category": "News/media website",
#    "name": "The Church Of Nigeria: Anglican Communion - Akure Diocese (Social Webpage)",
#    "id": "143748352345882"
#   },
#   {
#    "category": "Local business",
#    "name": "Dise\u00f1o Web y Social Media",
#    "id": "389293934485009"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web to Print",
#    "id": "309361589082975"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Grafdom - Web Design & Social Media",
#    "id": "190124415513"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead ziguinchor",
#    "id": "654808337965974"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "SociablWeb - Social Media News, SEO Tips",
#    "id": "446376028729715"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SEO Workers - Forensic SEO & Social Semantic Web Consulting",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "22362057425"
#   },
#   {
#    "category": "Local business",
#    "name": "~ SocialFly ~ Dise\u00f1o Web 2.0",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "317064404977552"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web",
#    "id": "1396212420669170"
#   },
#   {
#    "category": "Work position",
#    "name": "Social Web",
#    "id": "1549877305249290"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webunet - author of \"SEO & Social Media Marketing Guide\"",
#    "id": "355523558807"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar patte d'oie",
#    "id": "1570344376520742"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Website",
#    "id": "1409211522669854"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Web Social Marketing",
#    "id": "161192167329576"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar mermoz sacre coeur",
#    "id": "758697517535830"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social CR",
#    "id": "162780077207016"
#   },
#   {
#    "category": "Professional services",
#    "name": "Grupo Konceptual / Web & Social Media Branding",
#    "id": "180011298723599"
#   },
#   {
#    "category": "News/media website",
#    "name": "La Psych\u00e9 du Web Social",
#    "id": "226268934063345"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Buzz Websites",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "195634827182774"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Dashboard Professional and Tech: Web Development",
#    "id": "884698041558064"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web2social",
#    "id": "127415450642739"
#   },
#   {
#    "category": "University",
#    "name": "Master Universitario in \"Web communication & social media\"",
#    "category_list": [
#     {
#      "id": "108051929285833",
#      "name": "College & University"
#     }
#    ],
#    "id": "291350937559881"
#   },
#   {
#    "category": "Company",
#    "name": "Social Semantic Web",
#    "id": "36575011414"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "SocialWebCoding",
#    "id": "155266187877368"
#   },
#   {
#    "category": "Local business",
#    "name": "MerlinFX Web Email Marketing Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "139004380018"
#   },
#   {
#    "category": "Company",
#    "name": "Fuzzbox Designs Limited - Web, Graphics, Social Media",
#    "id": "348306219052"
#   },
#   {
#    "category": "Professional services",
#    "name": "Ace Website And Social Media",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "437870413024484"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "iptaque, web social, formation",
#    "id": "241894749184616"
#   },
#   {
#    "category": "Transport/freight",
#    "name": "Ezymove - NZ Social Freight Website",
#    "id": "149753265216860"
#   },
#   {
#    "category": "Company",
#    "name": "Social Webfashion",
#    "id": "476630749055988"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "TAG - Social Web Radio",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "226795074081704"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Katink web design & social media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "400114793423652"
#   },
#   {
#    "category": "Book",
#    "name": "PR im Social Web",
#    "id": "161347393888030"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web&Social Life - Italy",
#    "id": "162181413905627"
#   },
#   {
#    "category": "Education",
#    "name": "Web ENSFLLA Social",
#    "id": "218781014813739"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Lise Elder Web Design/Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "490355501021792"
#   },
#   {
#    "category": "Education",
#    "name": "Lauren Webb - A Social Studies Life",
#    "category_list": [
#     {
#      "id": "108557642554592",
#      "name": "Educational Service"
#     }
#    ],
#    "id": "500943803329283"
#   },
#   {
#    "category": "Business services",
#    "name": "Monea Social Web Marketing",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "576009755850788"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Digital For Dummies | Social, Web & other Technical Stuff",
#    "id": "476313985731653"
#   },
#   {
#    "category": "Software",
#    "name": "Fimark's Family Reunion Planner Social Web App",
#    "id": "119054884844075"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "Sarah Webster Fabio Center for Social Justice",
#    "category_list": [
#     {
#      "id": "2603",
#      "name": "Non-Profit Organization"
#     }
#    ],
#    "id": "662567650459545"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Mobile Social Web Consulting",
#    "id": "323337601029865"
#   },
#   {
#    "category": "App page",
#    "name": "Social Media Marketing using FB Websites",
#    "id": "472727666074315"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Business",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "620197398021531"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SeashoreWeb Social Media Marketing",
#    "id": "106838049410541"
#   },
#   {
#    "category": "Work position",
#    "name": "Social Media/Webb",
#    "id": "1488589091395050"
#   },
#   {
#    "category": "News/media website",
#    "name": "Advertising on the Web",
#    "id": "28705232393"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webius",
#    "category_list": [
#     {
#      "id": "177721448951559",
#      "name": "Workplace & Office"
#     }
#    ],
#    "id": "353444191416919"
#   },
#   {
#    "category": "Community",
#    "name": "Web COmmunities for Statistics for Social Innovation",
#    "id": "1398644970370772"
#   },
#   {
#    "category": "Software",
#    "name": "Socialspy Social Website Marketing Software",
#    "id": "468155203305128"
#   },
#   {
# ...
#    "name": "Paranormal Minds-\"A Social Media Webcast\"",
#    "id": "456473431065014"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Esther Szczerba - Web & Marketing Solutions, Social Media",
#    "id": "272044382898925"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Web Academy",
#    "id": "133517650020227"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Mais4 Social Web",
#    "id": "201920803163928"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "WebSocial2.0",
#    "id": "262868793734822"
#   },
#   {
#    "category": "Local business",
#    "name": "CDA - web site design and social media marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "199732070036794",
#      "name": "Artistic Services"
#     }
#    ],
#    "id": "127537383928865"
#   },
#   {
#    "category": "Community",
#    "name": "YL WebStudio",
#    "id": "381407298588705"
#   },
#   {
#    "category": "Book",
#    "name": "Informe APEI sobre Web Social",
#    "id": "33274669157"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Chaser Media - Social Media, Web Design and Photography Services",
#    "id": "195822857133037"
#   },
#   {
#    "category": "Attractions/things to do",
#    "name": "Social Media Team - Web Unit",
#    "id": "599676153457408"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial Business Solutions",
#    "id": "444124702299250"
#   },
#   {
#    "category": "Professional services",
#    "name": "Impulsive Labs Web Design & Social Media Management",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "261688960613759"
#   },
#   {
#    "category": "News/media website",
#    "name": "Web Analytics, Social Media and Digital marketing",
#    "id": "240539769321965"
#   },
#   {
#    "category": "Business person",
#    "name": "Virtuallinda - Web Design & Social Media Training for the Busy Professional",
#    "id": "88492397926"
#   },
#   {
#    "category": "Professional services",
#    "name": "SWM - Social Web Management",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "464943686887751"
#   },
#   {
#    "category": "Product/service",
#    "name": "OC Media Works - Website Design, Social Media, SEO & Online Marketing",
#    "id": "119488541409785"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Manager | Web e Social Media Marketing",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "147374031981368"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Bee Social",
#    "id": "180012895477291"
#   },
#   {
#    "category": "Professional services",
#    "name": "Lucas K. Williams: Web, Tech and Social Media Marketing GURU",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "147467965376263"
#   },
#   {
#    "category": "Professional services",
#    "name": "SocialMedia webmarketing School",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "624821100963943"
#   },
#   {
#    "category": "Website",
#    "name": "First Rank Marketing - SEO, Social Media, & Website Design",
#    "id": "111815885571826"
#   },
#   {
#    "category": "Business services",
#    "name": "Web Social Marketing",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "162081643861223"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Siti Web Social Marketing claudio corti",
#    "id": "143481949191843"
#   },
#   {
#    "category": "Event planning/event services",
#    "name": "St Josephs Social Club Official Website",
#    "category_list": [
#     {
#      "id": "110290705711626",
#      "name": "Bar"
#     }
#    ],
#    "id": "779768515407764"
#   },
#   {
#    "category": "Business services",
#    "name": "Web Social Media Marketing",
#    "id": "405802852763407"
#   },
#   {
#    "category": "Product/service",
#    "name": "Pedro Novell\u00f3n. Social Media, usabilidad, anal\u00edtica web.",
#    "id": "116628195091389"
#   },
#   {
#    "category": "Local business",
#    "name": "Ewing Enterprise - Custom Website Packages, SEO Services,  Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "131829320161316"
#   },
#   {
#    "category": "Education",
#    "name": "ITE College West - Nitec in Social Media and Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "162257397196866"
#   },
#   {
#    "category": "Book",
#    "name": "Empfehlungsmarketing im Social Web - Das Buch",
#    "id": "343063572502618"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Bold Digital - Web Design, Development & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "252109291496458"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Network For Webmasters - WebmaisterPro",
#    "id": "207157179328797"
#   },
#   {
#    "category": "Website",
#    "name": "Social Media Domains, Websites and More",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "301049839941854"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SWM - Social Web Marketing",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "201955759826537"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "GO Social Website Design",
#    "id": "109035149170820"
#   },
#   {
#    "category": "Public figure",
#    "name": "Web Success Diva Social Internet Marketing",
#    "id": "51426770632"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Marketing Social Web",
#    "id": "317803944941323"
#   },
#   {
#    "category": "Interest",
#    "name": "List of social networking websites",
#    "id": "111063838916102"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "White Social Web",
#    "id": "593079957405930"
#   },
#   {
#    "category": "Community",
#    "name": "WebdDee Social Community",
#    "id": "134952703245683"
#   },
#   {
#    "category": "Product/service",
#    "name": "Packetmanxd - Web Design & Social Media",
#    "id": "585427021523043"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media App Design - Brand Web Direct",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "180204945400699"
#   },
#   {
#    "category": "Website",
#    "name": "Web and Social Media Designer Portfolio",
#    "id": "633515570032384"
#   },
#   {
#    "category": "Internet/software",
#    "name": "MURCON - Websites and Search, Email, and Social Media Marketing, Databases",
#    "id": "108029989217335"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "Social Media Club Davis/Weber",
#    "id": "213870391977281"
#   },
#   {
#    "category": "Local business",
#    "name": "WEB2NULL.at - Social Media WebDesign Agentur",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "107423162613389"
#   },
#   {
#    "category": "Product/service",
#    "name": "Designs by Desiree Business Solutions",
#    "id": "436943043033766"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Pelican Web Services",
#    "id": "446747078697655"
#   },
#   {
#    "category": "Local business",
#    "name": "SocialExecs | Social Media & Web Specialists",
#    "id": "105478339515932"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SEO E-Commerce Digital & Web Marketing Posizionamento Strategie Social",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     }
#    ],
#    "id": "255923714595921"
#   },
#   {
#    "category": "Local business",
#    "name": "MX - web & social marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "121637227912375"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar sicap libert\u00e9",
#    "id": "632311346885311"
#   },
#   {
#    "category": "Professional services",
#    "name": "Web Marketing & Social Media - Alessia Scomparin",
#    "id": "244498258987043"
#   },
#   {
#    "category": "Radio station",
#    "name": "Lina Web Radio Social",
#    "id": "243771532452812"
#   },
#   {
#    "category": "Website",
#    "name": "WebSocial.ly",
#    "id": "113759552036905"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Branding Services/Website Services",
#    "id": "1517835035125112"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Modo web & social media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "455357827936421"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Consulting Test Page",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "159918207405302"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "websiteinawink.com - website design & social media packages",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "208456249177473"
#   },
#   {
#    "category": "Website",
#    "name": "IMCurtain.com | Blogosphere & Social News Website",
#    "id": "317066358470"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialMedia Designs",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "173876899342866"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Instus - Social Media & Web Based Services",
#    "id": "462458733874919"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Fletcher Web Marketing | SEO | SEM | Social Media | Analytics",
#    "id": "339797189378903"
#   },
#   {
#    "category": "Product/service",
#    "name": "Prydemedia / Publicidad . PaginasWeb . SocialMedia",
#    "id": "143118435841062"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Southern Cross Web and Social Marketing",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "448918335184289"
#   },
#   {
#    "category": "University",
#    "name": "Social Media and Web Technologies",
#    "id": "273616712747412"
#   },
#   {
#    "category": "Business services",
#    "name": "Silvia Designs Web Graphics Promos Social Fashion",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "179576078750378",
#      "name": "Fashion Designer"
#     }
#    ],
#    "id": "317925481648006"
#   },
#   {
#    "category": "Software",
#    "name": "Web design and social media specialists",
#    "id": "553498398099834"
#   },
#   {
#    "category": "Business person",
#    "name": "Paul Haley - Web Design and Social Media",
#    "id": "229853217188491"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Web Solutions",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "182527338476147"
#   },
#   {
#    "category": "Company",
#    "name": "Zero It | Websites | Development | Smartphone Apps | SEO | Social Media |",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "109692079082500"
#   },
#   {
#    "category": "Computers",
#    "name": "Patricia Petinal \"Web social\"",
#    "id": "222532634528060"
#   },
#   {
#    "category": "Website",
#    "name": "No T\u00e9dio Social Web Links",
#    "id": "162519380529668"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialTechnia, marketing for the social web",
#    "id": "123400527718504"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Sikuro Web & Web Social Marketing",
#    "id": "116990318484769"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Gen Urbano, Social Media Manager,  Dise\u00f1o Gr\u00e1fico y Web",
#    "id": "431685836861152"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Semantic Web",
#    "id": "103989939638996"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Massick Media & Design | Graphic / Web / Social Media Design",
#    "id": "128138577262750"
#   },
#   {
#    "category": "Local business",
#    "name": "Onefoursix - Specialists in Design, Print, Social Media, and Websites.",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "197888373555475",
#      "name": "Printing Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "453613371345754"
#   },
#   {
#    "category": "Musical instrument",
#    "name": "Wesome Web & Social Media solutions",
#    "id": "461405120593275"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Marketing Tips & Tracks",
#    "id": "330326447014616"
#   },
#   {
#    "category": "News/media website",
#    "name": "Web Marketing et Communication Social Media",
#    "id": "488498934539529"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Dise\u00f1o web, Marketing digital y Social media",
#    "id": "330617290390990"
#   },
#   {
#    "category": "Local business",
#    "name": "LocalizerUK - Online Marketing, Social Media and Mobile Web Services",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "169424813098860"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "MySocialWeb.nl",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "389545474484483"
#   },
#   {
#    "category": "App page",
#    "name": "Web Master Social Media",
#    "id": "195512703929741"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Net Club Emission 100% WEB 100 %LYON",
#    "id": "230243223809910"
#   },
#   {
#    "category": "Local business",
#    "name": "Person Centred Designs- Web Design, SEO, and Social Media Marketing UK",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "45366739923"
#   },
#   {
#    "category": "Company",
#    "name": "Donkrea Agencia Dise\u00f1o Web y Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "616960891669526"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
mtsw_id = '146803958708175'
pp(g.get_object(mtsw_id))
# Out:
# {
#  "website": "http://miningthesocialweb.com",
#  "can_post": true,
#  "company_overview": "Like It here on Facebook!\n\nFollow @SocialWebMining on Twitter: http://twitter.com/SocialWebMining\n\nGet the source code for the revised and expanded second edition on GitHub: http://bit.ly/MiningTheSocialWeb2E\n\nGet the (now legacy) source code for the first edition on GitHub: http://bit.ly/SocialWebMining",
#  "mission": "Teaches you how to navigate the most popular social web APIs to access, collect, analyze, and visualize social web data with IPython Notebook and other easy to use Python packages and visualization tools.",
#  "founded": "January 2011",
#  "likes": 1790,
#  "parking": {
#   "street": 0,
#   "lot": 0,
#   "valet": 0
#  },
#  "general_info": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites - Get it at http://bit.ly/135dHfs",
#  "id": "146803958708175",
#  "category": "Book",
#  "has_added_app": false,
#  "talking_about_count": 8,
#  "is_community_page": false,
#  "username": "MiningTheSocialWeb",
#  "description": "Facebook, Twitter, LinkedIn, Google+, and other social web properties generate a wealth of valuable social data, but how can you tap into this data and discover who\u2019s connecting with whom, which insights are lurking just beneath the surface, and what people are talking about? This book shows you how to answer these questions and many more. Each chapter combines popular and useful social web data with analysis techniques and visualization to help you find the needles in the social haystack that you've been looking for\u2014as well as many you probably didn't even know existed.\n\nIn this expanded and thoroughly revised second edition you\u2019ll learn how to:\n\n* Navigate the most popular social web APIs to access, collect, analyze, and visualize social web data\n* Employ IPython Notebook and other easy to use Python packages such as the Natural Language Toolkit, NetworkX, and Matplotlib to efficiently sift through social web data as part of an experimentally-driven approach to discovering insights in social web data\n* Apply advanced text-mining techniques such as TF-IDF, cosine similarity, collocation analysis, document summarization, and clique detection to human language data that you'll encounter all over the web\n* Bootstrap interest graphs by discovering latent affinities between people, programming languages, and coding projects from GitHub data\n* Visualize social web data with D3, a state-of-the-art HTML5 and JavaScript toolkit\n\nThe book's source code is maintained in a GitHub repository maintained by the author and can be deployed as turn-key virtual machine with each chapter's source code presented in an interactive and easy to use IPython Notebook format. No complex third-party installations or advanced Python knowledge is required to get the most out of this book.",
#  "awards": "Jolt Productivity Award (1st Ed.) -  http://drdobbs.com/joltawards/231500080?pgno=6",
#  "genre": "Data Mining",
#  "checkins": 0,
#  "about": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites. Twitter: @SocialWebMining",
#  "name": "Mining the Social Web",
#  "release_date": "January 2011",
#  "cover": {
#   "source": "https://scontent-a.xx.fbcdn.net/hphotos-frc3/t31.0-8/p180x540/1073953_522831997772034_741301400_o.jpg",
#   "cover_id": 522831997772034,
#   "offset_x": 0,
#   "offset_y": 56
#  },
#  "were_here_count": 0,
#  "link": "https://www.facebook.com/MiningTheSocialWeb",
#  "is_published": true
# }

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))
# Out:
# {
#  "id": "http://shop.oreilly.com/product/0636920030195.do",
#  "shares": 244
# }
# {
#  "category": "Book",
#  "about": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "talking_about_count": 0,
#  "description": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "has_added_app": false,
#  "can_post": true,
#  "name": "Programming Collective Intelligence",
#  "link": "http://shop.oreilly.com/product/9780596529321.do",
#  "likes": 18,
#  "parking": {
#   "street": 0,
#   "lot": 0,
#   "valet": 0
#  },
#  "is_community_page": false,
#  "were_here_count": 0,
#  "checkins": 0,
#  "id": "221689464577245",
#  "is_published": true
# }

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print "Pepsi likes:", int_format(g.get_object(pepsi_id)['likes'])
print "Coke likes:", int_format(g.get_object(coke_id)['likes'])
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?limit=5&type=page&q=pepsi&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&offset=5&__after_id=enc_AezsSacPJScAi6eYWVbvC12aSK2JQJsq6vzyZaIPsqRHENKsDdJuGLSctM6DRl32KD1yNBE9pe5BUVQyQULnt2ov"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi",
#    "id": "339150749455906"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "PepsiCo",
#    "category_list": [
#     {
#      "id": "2252",
#      "name": "Food/Beverages"
#     }
#    ],
#    "id": "260431051694"
#   },
#   {
#    "category": "Community",
#    "name": "Pepsi Center WTC",
#    "category_list": [
#     {
#      "id": "179943432047564",
#      "name": "Concert Venue"
#     }
#    ],
#    "id": "374140015943779"
#   },
#   {
#    "category": "Sports team",
#    "name": "Pepsi Max Crew FPR",
#    "category_list": [
#     {
#      "id": "196083133750448",
#      "name": "Race Cars"
#     }
#    ],
#    "id": "150607624959898"
#   },
#   {
#    "category": "Company",
#    "name": "Pepsi Center",
#    "category_list": [
#     {
#      "id": "211155112228091",
#      "name": "Event Venue"
#     },
#     {
#      "id": "109976259083543",
#      "name": "Sports Venue & Stadium"
#     }
#    ],
#    "id": "111829892187838"
#   }
#  ]
# }
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?limit=5&type=page&q=coke&access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&offset=5&__after_id=enc_AezwW7cT3KAkayt7SbCtX6k4gF5LhzmPUh2yy3NuKwDk0cLku8Sz-Ve22zdrVOnvO31zeFeWHdIiBxXqKkbLt3ME"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola",
#    "id": "40796308305"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio",
#    "category_list": [
#     {
#      "id": "133436743388217",
#      "name": "Arts & Entertainment"
#     }
#    ],
#    "id": "16944632531"
#   },
#   {
#    "category": "Movie",
#    "name": "The Cokeville Miracle",
#    "id": "879251875424073"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola Zero M\u00e9xico",
#    "id": "124143809044"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola Life",
#    "id": "437854099622026"
#   }
#  ]
# }
# Pepsi likes:
# 33,999,736
# Coke likes:
# 89,791,250

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pp(g.get_connections(pepsi_id, 'feed'))
pp(g.get_connections(pepsi_id, 'links'))

pp(g.get_connections(coke_id, 'feed'))
pp(g.get_connections(coke_id, 'links'))
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/56381779049/feed?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=25&until=1414367256",
#   "previous": "https://graph.facebook.com/v1.0/56381779049/feed?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=25&since=1414393169&__previous=1"
#  },
#  "data": [
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xpa1/v/t1.0-9/s480x480/10421346_10202498875423848_928835646054440242_n.jpg?oh=96134f477517cd852b6707dfc00b0670&oe=54F5A78A",
#    "from": {
#     "id": "1553952107",
#     "name": "Rebecca Duncan Campbell"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10202498875423848",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10202498875423848",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:59:29+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10202498875423848&set=o.56381779049&type=1",
#    "object_id": "10202498875423848",
#    "created_time": "2014-10-27T06:59:29+0000",
#    "message": "Stop buy in enjoysome Pepsi\nWith a few bones!!!",
#    "type": "photo",
#    "id": "56381779049_10202498875423848",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "from": {
#     "id": "1553952107",
#     "name": "Rebecca Duncan Campbell"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152943057494050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152943057494050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:52:13+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T06:52:13+0000",
#    "message": "Enjoy the soft drink of Pepsi!!!\n With a few pirates in Lorain! !!!",
#    "type": "status",
#    "id": "56381779049_10152943057494050"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-b-a.akamaihd.net/hphotos-ak-xfp1/v/t1.0-9/s480x480/10599354_10202498849783207_6367791612189425399_n.jpg?oh=f5015b0eb21be84020963c12cf09698e&oe=54DFA20F&__gda__=1425379574_e43407339be707e839be40c4cf0d0acf",
#    "from": {
#     "id": "1553952107",
#     "name": "Rebecca Duncan Campbell"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10202498849783207",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10202498849783207",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:49:09+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10202498849783207&set=o.56381779049&type=1",
#    "object_id": "10202498849783207",
#    "created_time": "2014-10-27T06:49:09+0000",
#    "message": "The pirate ship in Lorain\n Grrr having a Pepsi",
#    "type": "photo",
#    "id": "56381779049_10202498849783207",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "id": "100006330788861",
#     "name": "Chanel Manning"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152943029769050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152943029769050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:23:44+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T06:23:44+0000",
#    "message": "A few years back around the holidays you guys had the limited edition pepsi spice i never seen it again bring it back please :) ?",
#    "type": "status",
#    "id": "56381779049_10152943029769050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQBCDs0U86fbKxvc&w=158&h=158&url=https%3A%2F%2Flh5.googleusercontent.com%2F-D2GNAqPotpE%2FVE3htU07SmI%2FAAAAAAAAA2o%2FoBXiOSf_rjs%2Fw674-h445-no%2FDOGMA.jpg",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "name": "lh5.googleusercontent.com",
#    "caption": "lh5.googleusercontent.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496280240649574",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496280240649574",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:14:46+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://lh5.googleusercontent.com/-D2GNAqPotpE/VE3htU07SmI/AAAAAAAAA2o/oBXiOSf_rjs/w674-h445-no/DOGMA.jpg",
#    "created_time": "2014-10-27T06:14:46+0000",
#    "message": "<img src=\"https://lh5.googleusercontent.com/-D2GNAqPotpE/VE3htU07SmI/AAAAAAAAA2o/oBXiOSf_rjs/w674-h445-no/DOGMA.jpg\">",
#    "type": "link",
#    "id": "56381779049_1496280240649574",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQBgDtHtqZi_GAQG&w=158&h=158&url=https%3A%2F%2Fs3.amazonaws.com%2Fewv-ebay%2Fcontentbox1.png",
#    "from": {
#     "id": "100007805370893",
#     "name": "Stephen Hall"
#    },
#    "name": "Easy Web Video - eBay",
#    "caption": "www.easywebvideo.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1489374174666081",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1489374174666081",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:26:00+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://jvz9.com/c/239153/121065",
#    "created_time": "2014-10-27T04:26:00+0000",
#    "message": "You can sell more than physical products on E-bay..yiou can sell your services. e-products  virtually anything you want.find out more right here.watch Todd Gross evplain it in this video .get a free..pdf on how to  profit with E-bay  if you make like you are leaving the page,.....\n\nhttp://jvz9.com/c/239153/121065",
#    "type": "link",
#    "id": "56381779049_1489374174666081",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif"
#   },
#   {
#    "from": {
#     "id": "100000530514303",
#     "name": "Catherine Bernard Sousis Stone"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942866969050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942866969050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:13:04+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T04:13:04+0000",
#    "message": "Love My Pepsi!!!!",
#    "type": "status",
#    "id": "56381779049_10152942866969050"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xfp1/v/t1.0-9/p480x480/1609723_761373890602438_3170576559037805410_n.jpg?oh=962dc67e6d7455b8ca622953f690e583&oe=54EB3E55",
#    "from": {
#     "id": "100001895029471",
#     "name": "Dylan Vanhalen"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/761373890602438",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/761373890602438",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T02:54:40+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=761373890602438&set=o.56381779049&type=1",
#    "object_id": "761373890602438",
#    "created_time": "2014-10-27T02:54:40+0000",
#    "type": "photo",
#    "id": "56381779049_761373890602438",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-a-a.akamaihd.net/hphotos-ak-xpa1/v/t1.0-9/10351445_796947883701343_6909918180870923821_n.jpg?oh=fe0c48613cf88679ae41b796048438b2&oe=54E26210&__gda__=1421102504_65b8bee2cae179cc99a63a596579212c",
#    "from": {
#     "id": "100001584151967",
#     "name": "Jed McCastle"
#    },
#    "message_tags": {
#     "155": [
#      {
#       "length": 12,
#       "offset": 155,
#       "type": "page",
#       "id": "21278871488",
#       "name": "Mountain Dew"
#      }
#     ],
#     "120": [
#      {
#       "length": 5,
#       "offset": 120,
#       "type": "page",
#       "id": "10139643057",
#       "name": "Lay's"
#      }
#     ],
#     "108": [
#      {
#       "length": 7,
#       "offset": 108,
#       "type": "page",
#       "id": "24497276164",
#       "name": "Doritos"
#      }
#     ],
#     "65": [
#      {
#       "length": 14,
#       "offset": 65,
#       "type": "page",
#       "id": "160513490833",
#       "name": "Little Caesars"
#      }
#     ],
#     "176": [
#      {
#       "length": 9,
#       "offset": 176,
#       "type": "page",
#       "id": "40796308305",
#       "name": "Coca-Cola"
#      }
#     ],
#     "189": [
#      {
#       "length": 9,
#       "offset": 189,
#       "type": "page",
#       "id": "8605796091",
#       "name": "Diet Coke"
#      }
#     ],
#     "231": [
#      {
#       "length": 9,
#       "offset": 231,
#       "type": "page",
#       "id": "258431634354150",
#       "name": "Scootaloo"
#      }
#     ],
#     "169": [
#      {
#       "length": 5,
#       "offset": 169,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942665094050",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-10-27T02:14:06+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Little Caesars",
#       "id": "160513490833"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Doritos",
#       "id": "24497276164"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Lay's",
#       "id": "10139643057"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Mountain Dew",
#       "id": "21278871488"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Diet Coke",
#       "id": "8605796091"
#      },
#      {
#       "category": "Fictional character",
#       "name": "Scootaloo",
#       "id": "258431634354150"
#      },
#      {
#       "category": "Fictional character",
#       "name": "Scootaloo",
#       "id": "258431634354150"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=796947883701343&set=o.258431634354150&type=1",
#    "object_id": "796947883701343",
#    "created_time": "2014-10-27T02:14:06+0000",
#    "message": "This Tuesday,\n12:00 PM - Watching Clue (Movie) while we eat some Little Caesars pizza, chips of your choice Doritos, or Lay's and some pop of your choice, Mountain Dew, Pepsi, Coca-Cola or Diet Coke. What's your pick of each snack Scootaloo?",
#    "type": "photo",
#    "id": "56381779049_10152942665094050",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-g-a.akamaihd.net/hphotos-ak-xpa1/v/t1.0-9/1393712_796946677034797_7817662680188086150_n.jpg?oh=897b3c89f6e36a70b1f46251b143fb86&oe=54AA8340&__gda__=1424658301_4db9c8fae65ff13d537043adb706515c",
#    "from": {
#     "id": "100001584151967",
#     "name": "Jed McCastle"
#    },
#    "message_tags": {
#     "156": [
#      {
#       "length": 12,
#       "offset": 156,
#       "type": "page",
#       "id": "21278871488",
#       "name": "Mountain Dew"
#      }
#     ],
#     "190": [
#      {
#       "length": 9,
#       "offset": 190,
#       "type": "page",
#       "id": "8605796091",
#       "name": "Diet Coke"
#      }
#     ],
#     "121": [
#      {
#       "length": 5,
#       "offset": 121,
#       "type": "page",
#       "id": "10139643057",
#       "name": "Lay's"
#      }
#     ],
#     "109": [
#      {
#       "length": 7,
#       "offset": 109,
#       "type": "page",
#       "id": "24497276164",
#       "name": "Doritos"
#      }
#     ],
#     "66": [
#      {
#       "length": 14,
#       "offset": 66,
#       "type": "page",
#       "id": "160513490833",
#       "name": "Little Caesars"
#      }
#     ],
#     "177": [
#      {
#       "length": 9,
#       "offset": 177,
#       "type": "page",
#       "id": "40796308305",
#       "name": "Coca-Cola"
#      }
#     ],
#     "232": [
#      {
#       "length": 10,
#       "offset": 232,
#       "type": "page",
#       "id": "431499250228843",
#       "name": "AppleBloom"
#      }
#     ],
#     "170": [
#      {
#       "length": 5,
#       "offset": 170,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942660534050",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-10-27T02:11:09+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Little Caesars",
#       "id": "160513490833"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Doritos",
#       "id": "24497276164"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Lay's",
#       "id": "10139643057"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Mountain Dew",
#       "id": "21278871488"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Diet Coke",
#       "id": "8605796091"
#      },
#      {
#       "category": "Fictional character",
#       "name": "AppleBloom",
#       "id": "431499250228843"
#      },
#      {
#       "category": "Fictional character",
#       "name": "AppleBloom",
#       "id": "431499250228843"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=796946677034797&set=o.431499250228843&type=1",
#    "object_id": "796946677034797",
#    "created_time": "2014-10-27T02:11:09+0000",
#    "message": "This Tuesday,\n\n12:00 PM - Watching Clue (Movie) while we eat some Little Caesars pizza, chips of your choice Doritos, or Lay's and some pop of your choice, Mountain Dew, Pepsi, Coca-Cola or Diet Coke. What's your pick of each snack AppleBloom?",
#    "type": "photo",
#    "id": "56381779049_10152942660534050",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xfp1/v/t1.0-9/1908443_796944977034967_8133200193719798091_n.jpg?oh=345959a09566b21740257bfd6352e458&oe=54E005BE",
#    "from": {
#     "id": "100001584151967",
#     "name": "Jed McCastle"
#    },
#    "message_tags": {
#     "156": [
#      {
#       "length": 12,
#       "offset": 156,
#       "type": "page",
#       "id": "21278871488",
#       "name": "Mountain Dew"
#      }
#     ],
#     "190": [
#      {
#       "length": 9,
#       "offset": 190,
#       "type": "page",
#       "id": "8605796091",
#       "name": "Diet Coke"
#      }
#     ],
#     "121": [
#      {
#       "length": 5,
#       "offset": 121,
#       "type": "page",
#       "id": "10139643057",
#       "name": "Lay's"
#      }
#     ],
#     "109": [
#      {
#       "length": 7,
#       "offset": 109,
#       "type": "page",
#       "id": "24497276164",
#       "name": "Doritos"
#      }
#     ],
#     "66": [
#      {
#       "length": 14,
#       "offset": 66,
#       "type": "page",
#       "id": "160513490833",
#       "name": "Little Caesars"
#      }
#     ],
#     "177": [
#      {
#       "length": 9,
#       "offset": 177,
#       "type": "page",
#       "id": "40796308305",
#       "name": "Coca-Cola"
#      }
#     ],
#     "232": [
#      {
#       "length": 13,
#       "offset": 232,
#       "type": "page",
#       "id": "360253704041593",
#       "name": "Sweetie Belle"
#      }
#     ],
#     "170": [
#      {
#       "length": 5,
#       "offset": 170,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942658234050",
#      "name": "Comment"
#     }
#    ],
#    "updated_time": "2014-10-27T02:09:49+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Little Caesars",
#       "id": "160513490833"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Doritos",
#       "id": "24497276164"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Lay's",
#       "id": "10139643057"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Mountain Dew",
#       "id": "21278871488"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Diet Coke",
#       "id": "8605796091"
#      },
#      {
#       "category": "Musician/band",
#       "name": "Sweetie Belle",
#       "id": "360253704041593"
#      },
#      {
#       "category": "Musician/band",
#       "name": "Sweetie Belle",
#       "id": "360253704041593"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=796944977034967&set=o.360253704041593&type=1",
#    "object_id": "796944977034967",
#    "created_time": "2014-10-27T02:09:49+0000",
#    "message": "This Tuesday,\n\n12:00 PM - Watching Clue (Movie) while we eat some Little Caesars pizza, chips of your choice Doritos, or Lay's and some pop of your choice, Mountain Dew, Pepsi, Coca-Cola or Diet Coke. What's your pick of each snack Sweetie Belle?",
#    "type": "photo",
#    "id": "56381779049_10152942658234050",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xfp1/v/t1.0-9/p130x130/10426564_672496236199802_3605082807717661214_n.jpg?oh=afb150673f5293681c3e9afda7d7b7e1&oe=54AAD848",
#    "updated_time": "2014-10-27T01:47:26+0000",
#    "from": {
#     "id": "1225301625",
#     "name": "Andrew Gribble"
#    },
#    "name": "Mobile Uploads",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF5TURNd016ZzFNRFV3TWpNeU9UWTZNVFF4TkRNM05EWTBNem95",
#       "before": "WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF5TURNd016ZzFNREUxTURNeU1EZzZNVFF4TkRNM05EWXdNRG94"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "505663386",
#        "name": "Nastavia Berry"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2014-10-27T01:50:00+0000",
#       "message": "That's definitely u! No Pepsi, no talky. Lmao",
#       "id": "10203038490902943_10203038501503208",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1225301625",
#        "name": "Andrew Gribble"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2014-10-27T01:50:43+0000",
#       "message": "Yep!",
#       "id": "10203038490902943_10203038505023296",
#       "user_likes": false
#      }
#     ]
#    },
#    "message_tags": {
#     "26": [
#      {
#       "length": 5,
#       "offset": 26,
#       "type": "page",
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "object_id": "672496236199802",
#    "properties": [
#     {
#      "text": "Walk This Way Pet Sitting Services",
#      "href": "https://www.facebook.com/walkthiswaypetservices?ref=stream",
#      "name": "By"
#     }
#    ],
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/walkthiswaypetservices/photos/a.454796707969757.1073741829.451772391605522/672496236199802/?type=1",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAwNDU3MzQ1ODQ0",
#       "before": "MTUwNTc0MjIyNA=="
#      }
#     },
#     "data": [
#      {
#       "id": "1505742224",
#       "name": "Larry Webb"
#      },
#      {
#       "id": "100007400264507",
#       "name": "Melissa Sandoval"
#      },
#      {
#       "id": "100007132620017",
#       "name": "Marcella Smitherman"
#      },
#      {
#       "id": "100000192161464",
#       "name": "Donna Ridley"
#      },
#      {
#       "id": "664164133",
#       "name": "Antonio T T Teso"
#      },
#      {
#       "id": "100000457345844",
#       "name": "Pat Gribble"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T01:47:26+0000",
#    "message": "LOL, me before my morning Pepsi.",
#    "caption": "Sunday morning",
#    "type": "photo",
#    "id": "56381779049_10152942606614050",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-xaf1/v/t1.0-9/s480x480/10606297_980684825291896_5957992047343264030_n.jpg?oh=aad92488c797f151d37286763acd4646&oe=54B25ADC",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NTYwNTA0MDk0",
#       "before": "NjcwNTEzMTU1"
#      }
#     },
#     "data": [
#      {
#       "id": "670513155",
#       "name": "Heather Reeves Pokey"
#      },
#      {
#       "id": "100000602543989",
#       "name": "Joyce Boge Smith"
#      },
#      {
#       "id": "100005102348905",
#       "name": "Abby Voge"
#      },
#      {
#       "id": "100004102067211",
#       "name": "Kathleen Schneider"
#      },
#      {
#       "id": "560504094",
#       "name": "Jessica Ann"
#      }
#     ]
#    },
#    "from": {
#     "id": "100000511624944",
#     "name": "Kim Voge"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/980684825291896",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/980684825291896",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T01:38:15+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=980684825291896&set=o.56381779049&type=1",
#    "object_id": "980684825291896",
#    "created_time": "2014-10-27T01:38:15+0000",
#    "message": "Would this work for a good mascot?",
#    "type": "photo",
#    "id": "56381779049_980684825291896",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xfa1/v/t1.0-9/s480x480/1510946_1496177523993179_3159577562470170273_n.jpg?oh=343923d32381765104ef2b398a3971ce&oe=54F52E1B",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496177523993179",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496177523993179",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:41:19+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1496177523993179&set=o.56381779049&type=1",
#    "object_id": "1496177523993179",
#    "created_time": "2014-10-27T00:41:19+0000",
#    "message": "Re: Bible and Astronomy Slide 3/3",
#    "type": "photo",
#    "id": "56381779049_1496177523993179",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xap1/v/t1.0-9/s480x480/10685768_1496177400659858_881990432515448885_n.jpg?oh=f06ffb9a9d717340de3b90b5580c8d1f&oe=54F5487F",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496177400659858",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496177400659858",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:40:55+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1496177400659858&set=o.56381779049&type=1",
#    "object_id": "1496177400659858",
#    "created_time": "2014-10-27T00:40:55+0000",
#    "message": "Re: Bible and Astronomy Slide 2/3",
#    "type": "photo",
#    "id": "56381779049_1496177400659858",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-f-a.akamaihd.net/hphotos-ak-xfp1/v/t1.0-9/s480x480/10698446_1496177320659866_5623923136339549116_n.jpg?oh=ce170c9083a219afe5b36e73c2af2555&oe=54AE0339&__gda__=1424466920_9bea48e0fea755b8203c7d2ed8135a3c",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496177320659866",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496177320659866",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:40:35+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1496177320659866&set=o.56381779049&type=1",
#    "object_id": "1496177320659866",
#    "created_time": "2014-10-27T00:40:35+0000",
#    "message": "Re: Bible and Astronomy Slide 1/3",
#    "type": "photo",
#    "id": "56381779049_1496177320659866",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCQL3Et6Lwr9Zly&w=158&h=158&url=https%3A%2F%2Flh3.googleusercontent.com%2F-o67gdqIIz-8%2FVE2RpQVwKiI%2FAAAAAAAAA2A%2FBDE3Grpb6rA%2Fw512-h663-no%2FShould%252Bthe%252BBible%252Bbe%252Btaught%252Bin%252BAstronomy3.jpg",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "name": "lh3.googleusercontent.com",
#    "caption": "lh3.googleusercontent.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496175990659999",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496175990659999",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:36:22+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://lh3.googleusercontent.com/-o67gdqIIz-8/VE2RpQVwKiI/AAAAAAAAA2A/BDE3Grpb6rA/w512-h663-no/Should%2Bthe%2BBible%2Bbe%2Btaught%2Bin%2BAstronomy3.jpg",
#    "created_time": "2014-10-27T00:36:22+0000",
#    "message": "Bible \u2013 Science Document? YECism? Slide 3/3\n\n<img src=\"https://lh3.googleusercontent.com/-o67gdqIIz-8/VE2RpQVwKiI/AAAAAAAAA2A/BDE3Grpb6rA/w512-h663-no/Should%2Bthe%2BBible%2Bbe%2Btaught%2Bin%2BAstronomy3.jpg\">",
#    "type": "link",
#    "id": "56381779049_1496175990659999",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQC5TNL1d_hcAk_B&w=158&h=158&url=https%3A%2F%2Flh4.googleusercontent.com%2F-eoSOLdQfF_I%2FVE2RnKfqOPI%2FAAAAAAAAA14%2FsCrbAkCBrd4%2Fw512-h663-no%2FShould%252Bthe%252BBible%252Bbe%252Btaught%252Bin%252BAstronomy2.jpg",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "name": "lh4.googleusercontent.com",
#    "caption": "lh4.googleusercontent.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496175937326671",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496175937326671",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:36:08+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://lh4.googleusercontent.com/-eoSOLdQfF_I/VE2RnKfqOPI/AAAAAAAAA14/sCrbAkCBrd4/w512-h663-no/Should%2Bthe%2BBible%2Bbe%2Btaught%2Bin%2BAstronomy2.jpg",
#    "created_time": "2014-10-27T00:36:08+0000",
#    "message": "Bible \u2013 Science Document? YECism? Slide 2/3\n\n<img src=\"https://lh4.googleusercontent.com/-eoSOLdQfF_I/VE2RnKfqOPI/AAAAAAAAA14/sCrbAkCBrd4/w512-h663-no/Should%2Bthe%2BBible%2Bbe%2Btaught%2Bin%2BAstronomy2.jpg\">",
#    "type": "link",
#    "id": "56381779049_1496175937326671",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCKTHSv03l55wlV&w=158&h=158&url=https%3A%2F%2Flh3.googleusercontent.com%2F-VE7vWWjObCg%2FVE2RjaTYZjI%2FAAAAAAAAA1w%2FE69LRFFTcM8%2Fw512-h663-no%2FShould%252Bthe%252BBible%252Bbe%252Btaught%252Bin%252BAstronomy1.jpg",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "name": "lh3.googleusercontent.com",
#    "caption": "lh3.googleusercontent.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496175860660012",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496175860660012",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:35:53+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://lh3.googleusercontent.com/-VE7vWWjObCg/VE2RjaTYZjI/AAAAAAAAA1w/E69LRFFTcM8/w512-h663-no/Should%2Bthe%2BBible%2Bbe%2Btaught%2Bin%2BAstronomy1.jpg",
#    "created_time": "2014-10-27T00:35:53+0000",
#    "message": "Bible \u2013 Science Document? YECism? Slide 1/3\n\n<img src=\"https://lh3.googleusercontent.com/-VE7vWWjObCg/VE2RjaTYZjI/AAAAAAAAA1w/E69LRFFTcM8/w512-h663-no/Should%2Bthe%2BBible%2Bbe%2Btaught%2Bin%2BAstronomy1.jpg\">",
#    "type": "link",
#    "id": "56381779049_1496175860660012",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "id": "100002397843343",
#     "name": "Amy Hughes"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942446599050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152942446599050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:16:28+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T00:16:28+0000",
#    "message": "How would i get my hands on the Carolina Panthers Pepsi cans? I live in WV and my husband loves the Panthers and would like to get them for him.",
#    "type": "status",
#    "id": "56381779049_10152942446599050"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQAT-m9R59UT-quO&w=158&h=158&url=https%3A%2F%2Flh4.googleusercontent.com%2F-WFTaOcx3D_Q%2FVE2FEHw_Z5I%2FAAAAAAAAA1E%2FmRFXFJAilTE%2Fw674-h445-no%2FCDCWHOBible.jpg",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "name": "lh4.googleusercontent.com",
#    "caption": "lh4.googleusercontent.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496171453993786",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496171453993786",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:11:43+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://lh4.googleusercontent.com/-WFTaOcx3D_Q/VE2FEHw_Z5I/AAAAAAAAA1E/mRFXFJAilTE/w674-h445-no/CDCWHOBible.jpg",
#    "created_time": "2014-10-27T00:11:43+0000",
#    "message": "<img src=\"https://lh4.googleusercontent.com/-WFTaOcx3D_Q/VE2FEHw_Z5I/AAAAAAAAA1E/mRFXFJAilTE/w674-h445-no/CDCWHOBible.jpg\">",
#    "type": "link",
#    "id": "56381779049_1496171453993786",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQABHo6tBpf1lU0N&w=158&h=158&url=https%3A%2F%2Flh4.googleusercontent.com%2F-makm1ryWg_Q%2FVE15Phq_NbI%2FAAAAAAAAA0M%2Fo3f5YleFThM%2Fw674-h445-no%2F2800Lev2013.jpg",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "name": "lh4.googleusercontent.com",
#    "caption": "lh4.googleusercontent.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496171337327131",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496171337327131",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:11:02+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://lh4.googleusercontent.com/-makm1ryWg_Q/VE15Phq_NbI/AAAAAAAAA0M/o3f5YleFThM/w674-h445-no/2800Lev2013.jpg",
#    "created_time": "2014-10-27T00:11:02+0000",
#    "message": "The EBOLA Semen Thingy is going to be a problem for us Americans...\n\nLeviticus 20:13 - If a man has sexual relations with a man as one does with a woman, both of them have done what is detestable. They are to be put to death; their blood will be on their own heads. \n\n<img src=\"https://lh4.googleusercontent.com/-makm1ryWg_Q/VE15Phq_NbI/AAAAAAAAA0M/o3f5YleFThM/w674-h445-no/2800Lev2013.jpg\">",
#    "type": "link",
#    "id": "56381779049_1496171337327131",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-xpa1/v/t1.0-9/s480x480/10521367_1496170777327187_5360555112601346318_n.jpg?oh=d755044a80b768eeab065bb6cb815af2&oe=54B09972",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496170777327187",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496170777327187",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:08:11+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1496170777327187&set=o.56381779049&type=1",
#    "object_id": "1496170777327187",
#    "created_time": "2014-10-27T00:08:11+0000",
#    "type": "photo",
#    "id": "56381779049_1496170777327187",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-xfa1/v/t1.0-9/s480x480/10003310_1496170717327193_7090919501836682628_n.jpg?oh=49cadbc791d028355e07d9a011e409a9&oe=54E07976",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496170717327193",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496170717327193",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T00:07:52+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1496170717327193&set=o.56381779049&type=1",
#    "object_id": "1496170717327193",
#    "created_time": "2014-10-27T00:07:52+0000",
#    "type": "photo",
#    "id": "56381779049_1496170717327193",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-xpa1/v/t1.0-9/s480x480/559573_1496165907327674_6760234381398081847_n.jpg?oh=ce77b5303c44bbea05f01e5444c1bbde&oe=54E934E8",
#    "from": {
#     "id": "100008028362595",
#     "name": "Patrick Mullaney"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496165907327674",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1496165907327674",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-26T23:47:37+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1496165907327674&set=o.56381779049&type=1",
#    "object_id": "1496165907327674",
#    "created_time": "2014-10-26T23:47:37+0000",
#    "type": "photo",
#    "id": "56381779049_1496165907327674",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   }
#  ]
# }
# {
#  "data": []
# }
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/40796308305/feed?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=25&until=1414378771",
#   "previous": "https://graph.facebook.com/v1.0/40796308305/feed?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=25&since=1414395709&__previous=1"
#  },
#  "data": [
#   {
#    "from": {
#     "id": "100008335394358",
#     "name": "Nicole Abele"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657801203306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657801203306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T07:41:49+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T07:41:49+0000",
#    "message": "Bring back minute maid frozen lemon juice! thanks!",
#    "type": "status",
#    "id": "40796308305_10153657801203306"
#   },
#   {
#    "application": {
#     "name": "Facebook for Every Phone",
#     "id": "139682082719810"
#    },
#    "from": {
#     "id": "100007928957268",
#     "name": "Lilicash Lucas Dafatima"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657786703306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657786703306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T07:28:38+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T07:28:38+0000",
#    "message": "Goxt disso",
#    "type": "status",
#    "id": "40796308305_10153657786703306"
#   },
#   {
#    "from": {
#     "id": "100008089275098",
#     "name": "Lilian Mwangi"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657785333306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657785333306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T07:27:39+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T07:27:39+0000",
#    "message": "wonderful",
#    "type": "status",
#    "id": "40796308305_10153657785333306"
#   },
#   {
#    "from": {
#     "id": "100008089275098",
#     "name": "Lilian Mwangi"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657784583306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657784583306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T07:27:18+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T07:27:18+0000",
#    "message": "wonderful",
#    "type": "status",
#    "id": "40796308305_10153657784583306"
#   },
#   {
#    "picture": "https://fbcdn-vthumb-a.akamaihd.net/hvthumb-ak-xfp1/v/t15.0-10/10751509_10153657756608306_10153657756323306_29980_1115_b.jpg?oh=ab3668ad448b20d818e679716424a98a&oe=54F377D3&__gda__=1425323707_df9c84638b94ef7573988cd7fa900998",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NzY5MzU4NDg0",
#       "before": "MTAwMDAxOTc5MzAyMzk1"
#      },
#      "next": "https://graph.facebook.com/v1.0/40796308305_10153657756323306/likes?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=25&after=NzY5MzU4NDg0"
#     },
#     "data": [
#      {
#       "id": "100001979302395",
#       "name": "Sandra Bouma"
#      },
#      {
#       "id": "100002902099629",
#       "name": "Maeva Mendo"
#      },
#      {
#       "id": "100005256364966",
#       "name": "Omid Moradi"
#      },
#      {
#       "id": "1785874842",
#       "name": "Moa Melin Andersson"
#      },
#      {
#       "id": "1267639247",
#       "name": "Sharon Cremeens Wilson"
#      },
#      {
#       "id": "100007747392604",
#       "name": "Elijah Broadbent"
#      },
#      {
#       "id": "100000091670713",
#       "name": "Ewelina Wyroba"
#      },
#      {
#       "id": "100005255857465",
#       "name": "Nicole Hibon"
#      },
#      {
#       "id": "1336467437",
#       "name": "Dawood Jawad"
#      },
#      {
#       "id": "100001909679128",
#       "name": "Max Moody"
#      },
#      {
#       "id": "100002545167996",
#       "name": "Raul Salviano"
#      },
#      {
#       "id": "1845487196",
#       "name": "Anna Toth"
#      },
#      {
#       "id": "100001952852132",
#       "name": "Nevena Vrataric"
#      },
#      {
#       "id": "100000418271657",
#       "name": "Dale Henderson"
#      },
#      {
#       "id": "100007687294879",
#       "name": "Hansruedi Althaus"
#      },
#      {
#       "id": "100002861208668",
#       "name": "Marcos Vinicius"
#      },
#      {
#       "id": "100001829710304",
#       "name": "Costy Acsinte"
#      },
#      {
#       "id": "1090464609",
#       "name": "Filip Lennartsson"
#      },
#      {
#       "id": "1343027132",
#       "name": "Tomasz Szyma\u0144ski"
#      },
#      {
#       "id": "100005739040674",
#       "name": "Puck Lubking-Engelse"
#      },
#      {
#       "id": "1549213915",
#       "name": "Amanda Senior"
#      },
#      {
#       "id": "541753826",
#       "name": "\u00d6zge Ayd\u0131n"
#      },
#      {
#       "id": "100002681515456",
#       "name": "Susan Ruiz"
#      },
#      {
#       "id": "100002288291302",
#       "name": "Christel Klein Reesink"
#      },
#      {
#       "id": "769358484",
#       "name": "Lapuceisa Isa"
#      }
#     ]
#    },
#    "from": {
#     "category": "Food/beverages",
#     "name": "Coca-Cola",
#     "id": "40796308305"
#    },
#    "name": "Enjoy #minihappiness",
#    "privacy": {
#     "value": ""
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NDM=",
#       "before": "Njc="
#      },
#      "next": "https://graph.facebook.com/v1.0/40796308305_10153657756323306/comments?access_token=CAACEdEose0cBACArMCefkb50njbH2ijsvpHVyZAJEzsH8Tl3BlAhnyXmCvBMoxbTSbomMTDkgRyKSsFO7zR8HTes8sItWLeZBY86VsOkJWZBKfVZBOQeEEVAK6Ytxt1TC14ZBVCvet5rO6DdrKv4N6ODTE3B16ZAjl20LCIrQFUTGwiwlAmUXqbiNHqfiFxMjFgZBsKb1msjNqoy89aYXGsClQf9ox1LdsZD&limit=25&after=NDM%3D"
#     },
#     "data": [
#      {
#       "from": {
#        "id": "834129548",
#        "name": "Michael Richardson"
#       },
#       "like_count": 17,
#       "can_remove": false,
#       "created_time": "2014-10-27T07:13:17+0000",
#       "message": "proofread you posts",
#       "id": "10153657756323306_10153657756998306",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "100003401512546",
#        "name": "Minjeong Kim"
#       },
#       "message_tags": [
#        {
#         "length": 3,
#         "offset": 0,
#         "type": "user",
#         "id": "100006196445691",
#         "name": "\uc591\uc9c0\uc6d0"
#        },
#        {
#         "length": 2,
#         "offset": 4,
#         "type": "user",
#         "id": "100004900480846",
#         "name": "\uc218\uacbd"
#        }
#       ],
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2014-10-27T07:14:23+0000",
#       "message": "\uc591\uc9c0\uc6d0 \uc218\uacbd \ucf5c\ub77c\ub294 \ucf54\ud06c\uc9c0",
#       "id": "10153657756323306_10153657757708306",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1605061750",
#        "name": "Leone Edwards"
#       },
#       "like_count": 3,
# ...
#      }
#     ]
#    },
#    "from": {
#     "id": "100002447541146",
#     "name": "Marco Busatto"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/731109396980638",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/731109396980638",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:36:13+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbipad_",
#     "name": "Facebook for iPad",
#     "id": "173847642670370"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=731109396980638&set=o.40796308305&type=1",
#    "object_id": "731109396980638",
#    "created_time": "2014-10-27T06:36:13+0000",
#    "message": "Un omaggio alla mia bibita preferita! InstaxCocaCola.",
#    "type": "photo",
#    "id": "40796308305_731109396980638",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "id": "100005176453783",
#     "name": "Moses Odhiambo"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657717133306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657717133306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:35:52+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T06:35:52+0000",
#    "message": "Big UP",
#    "type": "status",
#    "id": "40796308305_10153657717133306"
#   },
#   {
#    "from": {
#     "id": "100000434471229",
#     "name": "Vinnie Viinn Mu\u00f1oz"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657695413306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657695413306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T06:12:25+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T06:12:25+0000",
#    "message": "Hola, quiero que hagan un poster con mi nombre en un refresco, MI NOMBRE NO ESTA :(",
#    "type": "status",
#    "id": "40796308305_10153657695413306"
#   },
#   {
#    "from": {
#     "id": "100006974464744",
#     "name": "Man U Van Msomali"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657665958306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657665958306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T05:33:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T05:33:51+0000",
#    "message": "ALHAMNDULILLAH",
#    "type": "status",
#    "id": "40796308305_10153657665958306"
#   },
#   {
#    "application": {
#     "name": "Facebook for Every Phone",
#     "id": "139682082719810"
#    },
#    "from": {
#     "id": "100004083820761",
#     "name": "Kiara Gonzalez"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657658608306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657658608306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T05:23:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T05:23:51+0000",
#    "message": "Kiero k mi nombre aparesca en las botellas d cocaccola. Kiara",
#    "type": "status",
#    "id": "40796308305_10153657658608306"
#   },
#   {
#    "from": {
#     "id": "100005093262946",
#     "name": "Hassan Allie"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657646588306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657646588306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T05:08:34+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T05:08:34+0000",
#    "message": "Abdul juma a.k.a diamon platinumz hehe i liked your show ''ukimuona'' at coke studio",
#    "type": "status",
#    "id": "40796308305_10153657646588306"
#   },
#   {
#    "application": {
#     "name": "Facebook for Every Phone",
#     "id": "139682082719810"
#    },
#    "from": {
#     "id": "100001554402597",
#     "name": "Rossini Trindade"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657638498306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657638498306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T05:00:10+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T05:00:10+0000",
#    "message": "Quero uma com meu nome rossini",
#    "type": "status",
#    "id": "40796308305_10153657638498306"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-b-a.akamaihd.net/hphotos-ak-xfa1/v/t1.0-9/s480x480/10393772_395218970645691_8953621419856996619_n.jpg?oh=6a4fd58e974b9c9023bce6939ed43f01&oe=54F61E27&__gda__=1424546805_92aa56e6b27ff9f6bf7392819e6da2ac",
#    "from": {
#     "id": "100004727739991",
#     "name": "Apple Marie Winrose Lopina"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/395218970645691",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/395218970645691",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:48:39+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=395218970645691&set=o.40796308305&type=1",
#    "object_id": "395218970645691",
#    "created_time": "2014-10-27T04:48:39+0000",
#    "message": "Cool! \\(^_^)/",
#    "type": "photo",
#    "id": "40796308305_395218970645691",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "id": "100001572987099",
#     "name": "Ray Neo Sol"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657622453306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657622453306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:41:47+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T04:41:47+0000",
#    "message": "Coca-Cola we won airtime worth 1000,you are running another promotion and we have not been awarded.Whats wrong?",
#    "type": "status",
#    "id": "40796308305_10153657622453306"
#   },
#   {
#    "application": {
#     "name": "Facebook for Every Phone",
#     "id": "139682082719810"
#    },
#    "from": {
#     "id": "100008061757945",
#     "name": "Osmedio Joao"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657611283306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657611283306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:27:59+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDA2MTcxNzA2NzU0",
#       "before": "MTAwMDA2MTcxNzA2NzU0"
#      }
#     },
#     "data": [
#      {
#       "id": "100006171706754",
#       "name": "\u0e40\u0e2d\u0e01\u0e0a\u0e31\u0e22 \u0e41\u0e01\u0e49\u0e27\u0e01\u0e4c\u0e25\u0e22\u0e32"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T04:27:59+0000",
#    "message": "Haloo....coca-cola.\nKeep going,you are in good hand's",
#    "type": "status",
#    "id": "40796308305_10153657611283306"
#   },
#   {
#    "from": {
#     "id": "100007858805961",
#     "name": "Salma Jan"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657610743306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657610743306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:27:11+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T04:27:11+0000",
#    "message": "<Coca Cola> Name He Pehcan He The Real Test I Like It",
#    "type": "status",
#    "id": "40796308305_10153657610743306"
#   },
#   {
#    "application": {
#     "namespace": "fbiphone",
#     "name": "Facebook for iPhone",
#     "id": "6628568379"
#    },
#    "from": {
#     "id": "1349723165",
#     "name": "Kat Biddle"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657600483306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657600483306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:16:23+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T04:16:23+0000",
#    "message": "please bring coke life to australia!! it would mean i can finally drink coke again!!!",
#    "type": "status",
#    "id": "40796308305_10153657600483306"
#   },
#   {
#    "from": {
#     "id": "100004483487561",
#     "name": "Alex Cross"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657588453306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657588453306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:06:19+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T04:06:19+0000",
#    "message": "Good Day,\n\nI would like to complement you on your initiative to put names on the labels of your product captioned \"shear a coke with\" and the person's name. I know there are millions of name however upon an extensive google search i realized my friend's name was not a part of this global undertaking. I am not aware of the process or how a person's name is chosen to be printed on a coca cola label but I would greatly appreciate it if his name can be added and distributed in Trinidad and Tobago. He deserves this because he is addicted to coao cola and supports your company buy purchasing your product. His name is Sachin. I hope to see \"Shear a coke with Sachin soon in our country. It would mean alot. Please forward this message to the necessary persons in your company who will also be able to assist. Thank You in advance for your kind considerations. \n\nSincerely,\nAlex.",
#    "type": "status",
#    "id": "40796308305_10153657588453306"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQDJYwf_mnXpWxvo&w=130&h=130&url=http%3A%2F%2Fi.ytimg.com%2Fvi%2FPZjCyqm09TA%2Fhqdefault.jpg",
#    "from": {
#     "id": "100001075501310",
#     "name": "Nancy R Kirk"
#    },
#    "name": "Neil Diamond - Coke Commercial #1",
#    "source": "http://www.youtube.com/v/PZjCyqm09TA?version=3&autohide=1&autoplay=1",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/791129254266251",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/791129254266251",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T04:02:38+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "link": "https://www.youtube.com/watch?v=PZjCyqm09TA&feature=share",
#    "created_time": "2014-10-27T04:02:38+0000",
#    "message": "I understand that Coke sales are down 'cause we're all so health conscious these days. But, back in 1967, Neil Diamond was singing for Coke! I'd buy Coke every day if Neil Diamond would write more Coke jingles! Aaahhh ... Coke! The '60s! Neil Diamond! It all takes me back! You've got to listen to this ... It's AWESOME!!!",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yj/r/v2OnaTyTQZE.gif",
#    "type": "video",
#    "id": "40796308305_791129254266251",
#    "description": "And now a word from our sponsors as we travel back to 1967 for a Coca-Cola commercial from Neil Diamond."
#   },
#   {
#    "from": {
#     "id": "660434984",
#     "name": "Jomjam Sitabutra"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657575728306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657575728306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T03:55:15+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T03:55:15+0000",
#    "message": "\u0e0b\u0e37\u0e49\u0e2d\u0e41\u0e1f\u0e19\u0e15\u0e49\u0e32\u0e19\u0e49\u0e33\u0e40\u0e02\u0e35\u0e22\u0e27\u0e41\u0e1a\u0e1a\u0e01\u0e23\u0e30\u0e1b\u0e4b\u0e2d\u0e07\u0e25\u0e30 10 \u0e1a\u0e32\u0e17\u0e21\u0e32\u0e08\u0e32\u0e01\u0e41\u0e21\u0e47\u0e04\u0e42\u0e04\u0e23 \u0e01\u0e23\u0e30\u0e1b\u0e4b\u0e2d\u0e07\u0e23\u0e31\u0e48\u0e27 \u0e2a\u0e32\u0e21\u0e32\u0e23\u0e16\u0e19\u0e33\u0e44\u0e1b\u0e40\u0e1b\u0e25\u0e35\u0e48\u0e22\u0e19\u0e17\u0e35\u0e48\u0e44\u0e2b\u0e19\u0e44\u0e14\u0e49\u0e1a\u0e49\u0e32\u0e07\u0e04\u0e30  \u0e0b\u0e37\u0e49\u0e2d\u0e21\u0e32\u0e40\u0e01\u0e34\u0e19 7 \u0e27\u0e31\u0e19\u0e41\u0e25\u0e49\u0e27 \u0e41\u0e21\u0e47\u0e04\u0e42\u0e04\u0e23\u0e04\u0e07\u0e44\u0e21\u0e48\u0e43\u0e2b\u0e49\u0e40\u0e1b\u0e25\u0e35\u0e48\u0e22\u0e19\u0e04\u0e30",
#    "type": "status",
#    "id": "40796308305_10153657575728306"
#   },
#   {
#    "from": {
#     "id": "1414202692",
#     "name": "Angel Presley Wilson"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657506443306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10153657506443306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2014-10-27T02:59:32+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2014-10-27T02:59:32+0000",
#    "message": "Nothing like a Cold Coke Cola!!",
#    "type": "status",
#    "id": "40796308305_10153657506443306"
#   }
#  ]
# }
# {
#  "data": []
# }

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "friends")['data']

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print likes
# Out:
# {u'Mar\xeda Fernanda Borge': [], u'Olliver Saul Flores': [{u'category': u'Movie character', u'created_time': u'2014-10-26T01:34:28+0000', u'name': u'The Head Shot KillaZ - LEMR', u'id': u'299382713562930'}, {u'category': u'Local business', u'created_time': u'2014-08-28T01:20:01+0000', u'name': u'El Local " Mod Games "', u'category_list': [{u'id': u'139823692748565', u'name': u'Computers & Electronics'}], u'id': u'257364217741166'}, {u'category': u'Musician/band', u'created_time': u'2014-06-02T14:02:53+0000', u'name': u'Zirel', u'id': u'844949845534305'}, {u'category': u'Artist', u'created_time': u'2014-05-13T17:51:32+0000', u'name': u'Spainfury Youtube', u'id': u'1381417018799184'}, {u'category': u'Musician/band', u'created_time': u'2014-04-01T04:41:08+0000', u'name': u'Meretrix-Music', u'id': u'609595555782412'}, {u'category': u'Entertainment website', u'created_time': u'2014-03-17T07:03:05+0000', u'name': u'Mejores v\xeddeos', u'id': u'647566031979234'}, {u'category': u'Entertainer', u'created_time': u'2014-01-30T04:29:51+0000', u'name': u'bysTaXx', u'id': u'134148526727065'}, {u'category': u'Public figure', u'created_time': u'2014-01-29T08:23:43+0000', u'name': u'Willyrex', u'id': u'162597417232850'}, {u'category': u'Entertainer', u'created_time': u'2013-12-26T01:04:20+0000', u'name': u'ElrubiusOMG', u'id': u'337992166223323'}, {u'category': u'Radio station', u'created_time': u'2013-10-23T22:26:36+0000', u'name': u'Amor1037 Veracruz', u'id': u'179211345525833'}, {u'category': u'Food/grocery', u'created_time': u'2013-06-24T23:08:37+0000', u'name': u'Retro Burguer', u'category_list': [{u'id': u'165679780146824', u'name': u'Food & Restaurant'}], u'id': u'608639835821149'}, {u'category': u'Games/toys', u'created_time': u'2013-06-01T18:57:04+0000', u'name': u'Team Fortress 2', u'id': u'66878763935'}, {u'category': u'Community organization', u'created_time': u'2013-05-16T22:11:19+0000', u'name': u"Comunidad Repak Gamer's", u'category_list': [{u'id': u'152880021441864', u'name': u'Community Organization'}], u'id': u'147737098713589'}, {u'category': u'Just for fun', u'created_time': u'2013-05-12T02:46:36+0000', u'name': u'Iniciape.Com - Entretenimiento', u'category_list': [{u'id': u'2631', u'name': u'Just For Fun'}], u'id': u'377070169026491'}, {u'category': u'Actor/director', u'created_time': u'2013-04-18T04:02:21+0000', u'name': u'Diosdelpan (Mrwolfsergio)', u'id': u'215381305225966'}, {u'category': u'Movie', u'created_time': u'2013-04-04T02:20:49+0000', u'name': u'Scary Movie', u'id': u'233224836695428'}, {u'category': u'Studio', u'created_time': u'2013-03-11T23:45:21+0000', u'name': u'Es mejor conversar en clases, que en el recreo .', u'id': u'534145053281872'}, {u'category': u'Travel/leisure', u'created_time': u'2013-02-01T01:25:48+0000', u'name': u'Extreme Travel Veracruz', u'category_list': [{u'id': u'186982054657561', u'name': u'Sports & Recreation'}], u'id': u'188007401270663'}, {u'category': u'Public figure', u'created_time': u'2013-01-22T02:05:31+0000', u'name': u'El Loco Torres', u'id': u'430898696983644'}, {u'category': u'App page', u'created_time': u'2013-01-02T01:32:01+0000', u'name': u'Facebook for Every Phone', u'id': u'331288023558058'}, {u'category': u'Company', u'created_time': u'2013-01-01T00:49:58+0000', u'name': u'Hack Games Face', u'id': u'314905468620862'}, {u'category': u'Musician/band', u'created_time': u'2012-12-24T17:51:20+0000', u'name': u'Ganjahr', u'id': u'406322922771441'}, {u'category': u'Community', u'created_time': u'2012-11-26T22:47:56+0000', u'name': u'Anonymous Hackers', u'id': u'375303575895168'}, {u'category': u'Community', u'created_time': u'2012-11-15T04:20:25+0000', u'name': u'Eres Todo Un Loquillo', u'id': u'119670001465068'}, {u'category': u'Movie', u'created_time': u'2012-11-15T04:20:21+0000', u'name': u'Scary Movie 4', u'id': u'113048328706458'}], u'Juan Pedro Luengas': [{u'category': u'Public figure', u'created_time': u'2014-08-12T01:50:01+0000', u'name': u'Yoshio Avila', u'id': u'32 ...

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print 'Top 10 likes amongst friends'
print pt
# Out:
# Top 10 likes amongst friends
# +-----------------------------------+------+
# | Name                              | Freq |
# +-----------------------------------+------+
# | Extreme Travel Veracruz           |    1 |
# | bysTaXx                           |    1 |
# | Yoshio Avila                      |    1 |
# | Nacion ESPN                       |    1 |
# | José Calzada                      |    1 |
# | NFL on ESPN                       |    1 |
# | Becky Hammon                      |    1 |
# | New England Patriots Cheerleaders |    1 |
# | Ana Gonzalez Bello                |    1 |
# | Boston Bruins                     |    1 |
# +-----------------------------------+------+

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print "Top 10 like categories for friends"
print pt
# Out:
# Top 10 like categories for friends
# +-----------------------+------+
# | Category              | Freq |
# +-----------------------+------+
# | Sports team           |    5 |
# | Movie                 |    4 |
# | Tv show               |    4 |
# | Public figure         |    4 |
# | Musician/band         |    3 |
# | Media/news/publishing |    3 |
# | Community             |    3 |
# | Actor/director        |    2 |
# | Magazine              |    2 |
# | Entertainer           |    2 |
# +-----------------------+------+

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print "Number of likes per friend"
print pt
# Out:
# Number of likes per friend
# +----------------------+-----------+
# | Friend               | Num Likes |
# +----------------------+-----------+
# | Olliver Saul Flores  |        25 |
# | Juan Pedro Luengas   |        25 |
# | María Fernanda Borge |         0 |
# +----------------------+-----------+

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print "My likes"
print pt

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print
print "My common likes with friends"
print pt
# Out:
# My likes
# +--------------------------------------------------------------------+
# | Name                                                               |
# +--------------------------------------------------------------------+
# | Onlinetv.planetfools.com                                           |
# | R bloggers                                                         |
# | Ingeniando Vida                                                    |
# | MBK Escuela de Música                                              |
# | Ru Gracia                                                          |
# | EPIC Lab - Centro ITAM de Creatividad, Innovación y Emprendimiento |
# | Tu Ola Mx                                                          |
# | Cloud9                                                             |
# | Carle ITAM                                                         |
# | Hardleash                                                          |
# | Restaurant Díaz                                                    |
# | Foreign Affairs Latinoamérica                                      |
# | Lolirot                                                            |
# | BrawL                                                              |
# | Skyshock                                                           |
# | Corsair Mexico                                                     |
# | INegocios                                                          |
# | Juan Luis Guerra                                                   |
# | Pooksie                                                            |
# | markett                                                            |
# | TheOddOne                                                          |
# | LoL México                                                         |
# | Dave Weckl                                                         |
# | Lyon Gaming                                                        |
# | H4ckerv2                                                           |
# +--------------------------------------------------------------------+
#
# My common likes with friends

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print "My similar friends (ranked)"
print pt

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist(ranked_friends.values())
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...

plt.figure() # Display the previous plot
plt.hist(ranked_friends.values(),
          bins=arange(1,max(ranked_friends.values()),1))
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-92c4586daa39> in <module>()
#      25 # how many friends.
#      26
# ---> 27 plt.hist(ranked_friends.values())
#      28 plt.xlabel('Bins (number of friends with shared likes)')
#      29 plt.ylabel('Number of shared likes in each bin')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2670                       histtype=histtype, align=align, orientation=orientation,
#    2671                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2672                       stacked=stacked, **kwargs)
#    2673         draw_if_interactive()
#    2674     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8024         # Massage 'x' for processing.
#    8025         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 8026         if isinstance(x, np.ndarray) or not iterable(x[0]):
#    8027             # TODO: support masked arrays;
#    8028             x = np.asarray(x)
#
# IndexError: list index out of range
# My similar friends (ranked)

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
print nxg

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = max(clique_sizes)
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print 'Num cliques:', num_cliques
print 'Avg clique size:', avg_clique_size
print 'Max clique size:', max_clique_size
print 'Num max cliques:', num_max_cliques
print
print 'Friends in all max cliques:'
print json.dumps(friends_in_all_max_cliques, indent=1)
print
print 'Max cliques:'
print json.dumps(max_cliques, indent=1)
# Out:
# Num cliques: 3
# Avg clique size: 2
# Max clique size: 2
# Num max cliques: 3
#
# Friends in all max cliques:
# [
#  "me"
# ]
#
# Max cliques:
# [
#  [
#   "me",
#   "Mar\u00eda Fernanda Borge"
#  ],
#  [
#   "me",
#   "Olliver Saul Flores"
#  ],
#  [
#   "me",
#   "Juan Pedro Luengas"
#  ]
# ]

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/ch02-facebook/viz/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
